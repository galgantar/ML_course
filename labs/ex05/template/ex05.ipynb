# %%
# Useful starting lines
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %load_ext autoreload
# %autoreload 2

# Load test module for sanity check
from test_utils import test
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Logistic Regression
# ## Classification Using Linear Regression
# Load your data.

# %%
from helpers import sample_data, load_data, standardize

# load data.
height, weight, gender = load_data()

# build sampled x and y.
seed = 1
y = np.expand_dims(gender, axis=1)
X = np.c_[height.reshape(-1), weight.reshape(-1)]
y, X = sample_data(y, X, seed, size_samples=200)
x, mean_x, std_x = standardize(X)

# %% [markdown]
# Use `least_squares` to compute w, and visualize the results.

# %%
from least_squares import least_squares
from plots import visualization


def least_square_classification_demo(y, x):
    """Least square demo

    Args:
        y:  shape=(N, 1)
        x:  shape=(N, 2)
    """
    # classify the data by linear regression
    tx = np.c_[np.ones((y.shape[0], 1)), x]
    # ***************************************************
    # INSERT YOUR CODE HERE
    # classify the data by linear regression: TODO
    # ***************************************************
    # w = least squares with respect to tx and y

    w, mse = least_squares(y, tx)

    # visualize your classification.
    visualization(y, x, mean_x, std_x, w, "classification_by_least_square")


least_square_classification_demo(y, x)

# %% [markdown]
# #### The `least_square_classification_demo` is expected to show
#
# ![1](./classification_by_least_square.png)

# %% [markdown]
# ## Logistic Regression

# %% [markdown]
# Compute your cost by negative log likelihood.

# %%
def sigmoid(t):
    """apply sigmoid function on t.

    Args:
        t: scalar or numpy array

    Returns:
        scalar or numpy array

    >>> sigmoid(np.array([0.1]))
    array([0.52497919])
    >>> sigmoid(np.array([0.1, 0.1]))
    array([0.52497919, 0.52497919])
    """
    
    return 1 / (1 + np.exp(-t))


test(sigmoid)
# Out:
# ✅ Your `sigmoid` passed 2 tests.

# %%
def calculate_loss(y, tx, w):
    """compute the cost by negative log likelihood.

    Args:
        y:  shape=(N, 1)
        tx: shape=(N, D)
        w:  shape=(D, 1)

    Returns:
        a non-negative loss

    >>> y = np.c_[[0., 1.]]
    >>> tx = np.arange(4).reshape(2, 2)
    >>> w = np.c_[[2., 3.]]
    >>> round(calculate_loss(y, tx, w), 8)
    1.52429481
    """
    assert y.shape[0] == tx.shape[0]
    assert tx.shape[1] == w.shape[0]

    # ***************************************************
    # INSERT YOUR CODE HERE
    # TODO
    # ***************************************************
    N = tx.shape[0]
    3
    # Note: this is one option
    # preds = sigmoid(tx @ w)
    # loss = -1/N * np.sum(y * np.log(preds) + (1 - y) * np.log(1 - preds))

    loss = 1/N * np.sum(-y * tx @ w + np.log(1 + np.exp(tx @ w))) # following the lecture exactly
    
    return float(loss)


test(calculate_loss)
# Out:
# ✅ Your `calculate_loss` passed 4 tests.

# %% [markdown]
# Note: you multiply loss by 1/N to get the average over all datapoints

# %%
def calculate_gradient(y, tx, w):
    """compute the gradient of loss.

    Args:
        y:  shape=(N, 1)
        tx: shape=(N, D)
        w:  shape=(D, 1)

    Returns:
        a vector of shape (D, 1)

    >>> np.set_printoptions(8)
    >>> y = np.c_[[0., 1.]]
    >>> tx = np.arange(6).reshape(2, 3)
    >>> w = np.array([[0.1], [0.2], [0.3]])
    >>> calculate_gradient(y, tx, w)
    array([[-0.10370763],
           [ 0.2067104 ],
           [ 0.51712843]])
    """
    # ***************************************************
    # INSERT YOUR CODE HERE
    # TODO
    # ***************************************************
    
    N = tx.shape[0]
    
    return tx.T @ (sigmoid(tx @ w) - y) / N


test(calculate_gradient)
# Out:
# ✅ Your `calculate_gradient` passed 5 tests.

# %% [markdown]
# ### Using Gradient Descent
# Implement your function to calculate the gradient for logistic regression.

# %%
def learning_by_gradient_descent(y, tx, w, gamma):
    """
    Do one step of gradient descent using logistic regression. Return the loss and the updated w.

    Args:
        y:  shape=(N, 1)
        tx: shape=(N, D)
        w:  shape=(D, 1)
        gamma: float

    Returns:
        loss: scalar number
        w: shape=(D, 1)

    >>> y = np.c_[[0., 1.]]
    >>> tx = np.arange(6).reshape(2, 3)
    >>> w = np.array([[0.1], [0.2], [0.3]])
    >>> gamma = 0.1
    >>> loss, w = learning_by_gradient_descent(y, tx, w, gamma)
    >>> round(loss, 8)
    0.62137268
    >>> w
    array([[0.11037076],
           [0.17932896],
           [0.24828716]])
    """
    # ***************************************************
    # INSERT YOUR CODE HERE
    # TODO
    # ***************************************************
    loss = calculate_loss(y, tx, w)
    grad = calculate_gradient(y, tx, w)
    w = w - gamma * grad
    return loss, w


test(learning_by_gradient_descent)
# Out:
# ✅ Your `learning_by_gradient_descent` passed 7 tests.

# %% [markdown]
# Demo!

# %%
from helpers import de_standardize


def logistic_regression_gradient_descent_demo(y, x):
    # init parameters
    max_iter = 10000
    threshold = 1e-8
    gamma = 0.5
    losses = []

    # build tx
    tx = np.c_[np.ones((y.shape[0], 1)), x]
    w = np.zeros((tx.shape[1], 1))

    # start the logistic regression
    for iter in range(max_iter):
        # get loss and update w.
        loss, w = learning_by_gradient_descent(y, tx, w, gamma)
        # log info
        if iter % 100 == 0:
            print("Current iteration={i}, loss={l}".format(i=iter, l=loss))
        # converge criterion
        losses.append(loss)
        if len(losses) > 1 and np.abs(losses[-1] - losses[-2]) < threshold:
            break
    # visualization
    visualization(
        y,
        x,
        mean_x,
        std_x,
        w,
        "classification_by_logistic_regression_gradient_descent",
        True,
    )
    print("loss={l}".format(l=calculate_loss(y, tx, w)))


logistic_regression_gradient_descent_demo(y, x)
# Out:
# Current iteration=0, loss=69.31471805599452
# Current iteration=100, loss=25.727807758229915
# Current iteration=200, loss=23.54612766230435
# Current iteration=300, loss=22.402749546644216
# Current iteration=400, loss=21.7439348921451
# Current iteration=500, loss=21.337866206030554
# Current iteration=600, loss=21.074981111571244
# Current iteration=700, loss=20.898450986240572
# Current iteration=800, loss=20.77655124329582
# Current iteration=900, loss=20.69051929895466
# Current iteration=1000, loss=20.62873819541177
# Current iteration=1100, loss=20.583744941158436
# Current iteration=1200, loss=20.55059872768725
# Current iteration=1300, loss=20.525946348042883
# Current iteration=1400, loss=20.507464518877036
# Current iteration=1500, loss=20.49351533097044
# Current iteration=1600, loss=20.482926953052655
# Current iteration=1700, loss=20.474850436405458
# Current iteration=1800, loss=20.468664114263547
# Current iteration=1900, loss=20.46390853160284
# Current iteration=2000, loss=20.460241400596175
# Current iteration=2100, loss=20.457405952827123
# Current iteration=2200, loss=20.45520841171981
# Current iteration=2300, loss=20.45350177115527
# Current iteration=2400, loss=20.45217399543565
# Current iteration=2500, loss=20.451139357783973
# Current iteration=2600, loss=20.450332031614316
# Current iteration=2700, loss=20.449701314932476
# Current iteration=2800, loss=20.44920804924756
# Current iteration=2900, loss=20.448821919174932
# Current iteration=3000, loss=20.44851940601575
# Current iteration=3100, loss=20.448282230082498
# Current iteration=3200, loss=20.448096160389255
# Current iteration=3300, loss=20.447950101893532
# Current iteration=3400, loss=20.447835393401817
# Current iteration=3500, loss=20.447745266029827
# Current iteration=3600, loss=20.447674424479203
# Current iteration=3700, loss=20.44761872257255
# Current iteration=3800, loss=20.44757491134206
# Current iteration=3900, loss=20.44754044311222
# Current iteration=4000, loss=20.447513318897478
# Current iteration=4100, loss=20.447491969377328
# Current iteration=4200, loss=20.447475161948805
# Current iteration=4300, loss=20.447461928065195
# Current iteration=4400, loss=20.447451506379434
# Current iteration=4500, loss=20.447443298216864
# Current iteration=4600, loss=20.447436832677525
# Current iteration=4700, loss=20.447431739267248
# Current iteration=4800, loss=20.447427726420557
# Current iteration=4900, loss=20.44742456463823
# Current iteration=5000, loss=20.44742207324164
# Current iteration=5100, loss=20.44742010996404
# Current iteration=5200, loss=20.447418562767943
# Current iteration=5300, loss=20.44741734341054
# loss=20.447416990693704

# %% [markdown]
# #### The `logistic_regression_gradient_descent_demo` is expected to show
#
# ![1](./classification_by_logistic_regression_gradient_descent.png)

# %% [markdown]
# Calculate your hessian below

# %%
def calculate_hessian(y, tx, w):
    """return the Hessian of the loss function.

    Args:
        y:  shape=(N, 1)
        tx: shape=(N, D)
        w:  shape=(D, 1)

    Returns:
        a hessian matrix of shape=(D, D)

    >>> y = np.c_[[0., 1.]]
    >>> tx = np.arange(6).reshape(2, 3)
    >>> w = np.array([[0.1], [0.2], [0.3]])
    >>> calculate_hessian(y, tx, w)
    array([[0.28961235, 0.3861498 , 0.48268724],
           [0.3861498 , 0.62182124, 0.85749269],
           [0.48268724, 0.85749269, 1.23229813]])
    """
    # ***************************************************
    # INSERT YOUR CODE HERE
    # calculate Hessian: TODO
    # ***************************************************
    
    N = tx.shape[0]
    preds = sigmoid(tx @ w)
    S = np.diag((preds * (1 - preds)).flatten()) # convert (N, 1) array to 1D array with flatten
    return 1/N * tx.T @ S @ tx


test(calculate_hessian)
# Out:
# ✅ Your `calculate_hessian` passed 4 tests.

# %% [markdown]
# Write a function below to return loss, gradient, and hessian.

# %%
def logistic_regression(y, tx, w):
    """return the loss, gradient of the loss, and hessian of the loss.

    Args:
        y:  shape=(N, 1)
        tx: shape=(N, D)
        w:  shape=(D, 1)

    Returns:
        loss: scalar number
        gradient: shape=(D, 1)
        hessian: shape=(D, D)

    >>> y = np.c_[[0., 1.]]
    >>> tx = np.arange(6).reshape(2, 3)
    >>> w = np.array([[0.1], [0.2], [0.3]])
    >>> loss, gradient, hessian = logistic_regression(y, tx, w)
    >>> round(loss, 8)
    0.62137268
    >>> gradient, hessian
    (array([[-0.10370763],
           [ 0.2067104 ],
           [ 0.51712843]]), array([[0.28961235, 0.3861498 , 0.48268724],
           [0.3861498 , 0.62182124, 0.85749269],
           [0.48268724, 0.85749269, 1.23229813]]))
    """
    # ***************************************************
    # INSERT YOUR CODE HERE
    # return loss, gradient, and Hessian: TODO
    # ***************************************************
    
    loss = calculate_loss(y, tx, w)
    grad = calculate_gradient(y, tx, w)
    hess = calculate_hessian(y, tx, w)
    return loss, grad, hess


test(logistic_regression)
# Out:
# ✅ Your `logistic_regression` passed 6 tests.

# %% [markdown]
# ### Using Newton's method
# Use Newton's method for logistic regression.

# %%
def learning_by_newton_method(y, tx, w, gamma):
    """
    Do one step of Newton's method.
    Return the loss and updated w.

    Args:
        y:  shape=(N, 1)
        tx: shape=(N, D)
        w:  shape=(D, 1)
        gamma: scalar

    Returns:
        loss: scalar number
        w: shape=(D, 1)

    >>> y = np.c_[[0., 0., 1., 1.]]
    >>> np.random.seed(0)
    >>> tx = np.random.rand(4, 3)
    >>> w = np.array([[0.1], [0.5], [0.5]])
    >>> gamma = 0.1
    >>> loss, w = learning_by_newton_method(y, tx, w, gamma)
    >>> round(loss, 8)
    0.71692036
    >>> w
    array([[-1.31876014],
           [ 1.0590277 ],
           [ 0.80091466]])
    """
    # ***************************************************
    # INSERT YOUR CODE HERE
    # return loss, gradient and Hessian: TODO
    # ***************************************************
    loss = calculate_loss(y, tx, w)
    grad = calculate_gradient(y, tx, w)
    hess = calculate_hessian(y, tx, w)
    # ***************************************************
    # INSERT YOUR CODE HERE
    # update w: TODO
    # ***************************************************
    
    # use np.linalg.solve instead of np.linalg.inv to avoid numerical instability
    w = w - gamma * np.linalg.solve(hess, grad) 

    return loss, w


test(learning_by_newton_method)
# Out:
# ✅ Your `learning_by_newton_method` passed 8 tests.

# %% [markdown]
# Note: we can use np.lingalg.solve to compute inverse*column for the entire matrix not just for one vector

# %% [markdown]
# demo

# %%
def logistic_regression_newton_method_demo(y, x):
    # init parameters
    max_iter = 100
    threshold = 1e-8
    lambda_ = 0.1
    gamma = 1.0
    losses = []

    # build tx
    tx = np.c_[np.ones((y.shape[0], 1)), x]
    w = np.zeros((tx.shape[1], 1))

    # start the logistic regression
    for iter in range(max_iter):
        # get loss and update w.
        loss, w = learning_by_newton_method(y, tx, w, gamma)
        # log info
        if iter % 1 == 0:
            print("Current iteration={i}, the loss={l}".format(i=iter, l=loss))

        # converge criterion
        losses.append(loss)
        if len(losses) > 1 and np.abs(losses[-1] - losses[-2]) < threshold:
            break
    # visualization
    visualization(
        y,
        x,
        mean_x,
        std_x,
        w,
        "classification_by_logistic_regression_newton_method",
        True,
    )
    print("loss={l}".format(l=calculate_loss(y, tx, w)))


logistic_regression_newton_method_demo(y, x)
# Out:
# Current iteration=0, the loss=0.6931471805599452
# Current iteration=1, the loss=0.31705776869547936
# Current iteration=2, the loss=0.23652293099675298
# Current iteration=3, the loss=0.20998733711242235
# Current iteration=4, the loss=0.2047819931861897
# Current iteration=5, the loss=0.20447559968244788
# Current iteration=6, the loss=0.2044741280881354
# Current iteration=7, the loss=0.20447412804945292
# loss=0.20447412804945295

# %% [markdown]
# #### The `logistic_regression_newton_method_demo` is expected to show
#
# ![1](./classification_by_logistic_regression_newton_method.png)

# %% [markdown]
# ### Using penalized logistic regression
# Fill in the function below.

# %%
def penalized_logistic_regression(y, tx, w, lambda_):
    """return the loss and gradient.

    Args:
        y:  shape=(N, 1)
        tx: shape=(N, D)
        w:  shape=(D, 1)
        lambda_: scalar

    Returns:
        loss: scalar number
        gradient: shape=(D, 1)

    >>> y = np.c_[[0., 1.]]
    >>> tx = np.arange(6).reshape(2, 3)
    >>> w = np.array([[0.1], [0.2], [0.3]])
    >>> lambda_ = 0.1
    >>> loss, gradient = penalized_logistic_regression(y, tx, w, lambda_)
    >>> round(loss, 8)
    0.62137268
    >>> gradient
    array([[-0.08370763],
           [ 0.2467104 ],
           [ 0.57712843]])
    """
    # ***************************************************
    # INSERT YOUR CODE HERE
    # return loss, gradient, and Hessian: TODO
    # ***************************************************
    N = tx.shape[0]
    preds = sigmoid(tx @ w)
    grad = -1/N * tx.T @ (y - preds) + 2 * lambda_ * w

    return calculate_loss(y, tx, w), grad

test(penalized_logistic_regression)
# Out:
# ✅ Your `penalized_logistic_regression` passed 7 tests.

# %%
def learning_by_penalized_gradient(y, tx, w, gamma, lambda_):
    """
    Do one step of gradient descent, using the penalized logistic regression.
    Return the loss and updated w.

    Args:
        y:  shape=(N, 1)
        tx: shape=(N, D)
        w:  shape=(D, 1)
        gamma: scalar
        lambda_: scalar

    Returns:
        loss: scalar number
        w: shape=(D, 1)

    >>> np.set_printoptions(8)
    >>> y = np.c_[[0., 1.]]
    >>> tx = np.arange(6).reshape(2, 3)
    >>> w = np.array([[0.1], [0.2], [0.3]])
    >>> lambda_ = 0.1
    >>> gamma = 0.1
    >>> loss, w = learning_by_penalized_gradient(y, tx, w, gamma, lambda_)
    >>> round(loss, 8)
    0.62137268
    >>> w
    array([[0.10837076],
           [0.17532896],
           [0.24228716]])
    """
    # ***************************************************
    # INSERT YOUR CODE HERE
    # return loss, gradient: TODO
    # ***************************************************
    loss, grad = penalized_logistic_regression(y, tx, w, lambda_)
    # ***************************************************
    # INSERT YOUR CODE HERE
    # update w: TODO
    # ***************************************************
    w = w - gamma * grad
    return loss, w


test(learning_by_penalized_gradient)
# Out:
# ✅ Your `learning_by_penalized_gradient` passed 9 tests.

# %%
def logistic_regression_penalized_gradient_descent_demo(y, x):
    # init parameters
    max_iter = 10000
    gamma = 0.5
    lambda_ = 0.0005
    threshold = 1e-8
    losses = []

    # build tx
    tx = np.c_[np.ones((y.shape[0], 1)), x]
    w = np.zeros((tx.shape[1], 1))

    # start the logistic regression
    for iter in range(max_iter):
        # get loss and update w.
        loss, w = learning_by_penalized_gradient(y, tx, w, gamma, lambda_)
        # log info
        if iter % 100 == 0:
            print("Current iteration={i}, loss={l}".format(i=iter, l=loss))
        # converge criterion
        losses.append(loss)
        if len(losses) > 1 and np.abs(losses[-1] - losses[-2]) < threshold:
            break
    # visualization
    visualization(
        y,
        x,
        mean_x,
        std_x,
        w,
        "classification_by_logistic_regression_penalized_gradient_descent",
        True,
    )
    print("loss={l}".format(l=calculate_loss(y, tx, w)))


logistic_regression_penalized_gradient_descent_demo(y, x)
# Out:
# Current iteration=0, loss=0.6931471805599452
# Current iteration=100, loss=0.25835336206313136
# Current iteration=200, loss=0.23768541265662857
# Current iteration=300, loss=0.22712668322710844
# Current iteration=400, loss=0.2211184138878508
# Current iteration=500, loss=0.2174333178698857
# Current iteration=600, loss=0.21504465517934657
# Current iteration=700, loss=0.21343008764925422
# Current iteration=800, loss=0.212302813494644
# Current iteration=900, loss=0.21149551766400648
# Current iteration=1000, loss=0.21090565347598225
# Current iteration=1100, loss=0.21046773835439972
# Current iteration=1200, loss=0.2101384845683434
# Current iteration=1300, loss=0.20988842069910987
# Current iteration=1400, loss=0.2096969707485196
# Current iteration=1500, loss=0.20954945801081148
# Current iteration=1600, loss=0.20943522174621151
# Current iteration=1700, loss=0.20934639893305243
# Current iteration=1800, loss=0.2092771154797812
# Current iteration=1900, loss=0.20922293642070286
# Current iteration=2000, loss=0.20918048405174872
# Current iteration=2100, loss=0.20914716752475251
# Current iteration=2200, loss=0.20912098803478935
# Current iteration=2300, loss=0.20910039632009852
# Current iteration=2400, loss=0.20908418704334317
# Current iteration=2500, loss=0.20907141961915415
# Current iteration=2600, loss=0.20906135829594882
# Current iteration=2700, loss=0.20905342644552197
# Current iteration=2800, loss=0.2090471714598741
# Current iteration=2900, loss=0.20904223764696395
# Current iteration=3000, loss=0.20903834520980788
# Current iteration=3100, loss=0.20903527388499335
# Current iteration=3200, loss=0.20903285017095866
# Current iteration=3300, loss=0.20903093733527944
# Current iteration=3400, loss=0.20902942758175372
# Current iteration=3500, loss=0.20902823590137642
# loss=0.20902797948572713

# %% [markdown]
# #### The `logistic_regression_penalized_gradient_descent_demo` is expected to show
#
# ![1](./classification_by_logistic_regression_penalized_gradient_descent.png)
